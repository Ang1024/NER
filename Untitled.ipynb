# %%
import pandas as pd

# %%
df = pd.read_csv("/home/anurag.chandrakar/Projects/Ontology/DiseaseNormalization/drug_indication_pair - drug_indication_pair.tsv", sep="\t")

# %%
df
# Out:
#                                                drug_name  \
# 0                                              Lepirudin
# 1                                              Cetuximab
# 2                                           Dornase alfa
# 3                                    Denileukin diftitox
# 4                                             Etanercept
# 5                                            Bivalirudin
# 6                                             Leuprolide
# 7                                  Peginterferon alfa-2a
# 8                                              Alteplase
# 9                                             Sermorelin
# 10                                    Interferon alfa-n1
# 11                                      Darbepoetin alfa
# 12                                             Urokinase
# 13                                             Goserelin
# 14                                             Reteplase
# ...

# %%
for i, x in enumerate(df['indication']):
    print x.replace("['", "").replace("']", "").split()
    break
# Out:
# ['For', 'the', 'treatment', 'of', 'heparin-induced', 'thrombocytopenia']
